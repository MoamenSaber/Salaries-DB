# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import io

# %% [markdown]
# # loading the data

# %%
# from google.colab import files 
# uploaded_file = files.upload()
# Data = pd.read_csv(io.BytesIO(uploaded_file['O_Salaries.csv']))
# Data

Data = pd.read_csv(r"F:\Amit (AI & ML)\(2) Data Science Preparation\Example Session 4\O_Salaries.csv")
Data
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # make a copy of the dataframe

# %%
df = Data.copy()
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # Check the head/ tail/ shape of the DataFrame

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
df.shape
# Out:
# (148654, 13)

# %% [markdown]
# # Use the .info() method to find out how many entries there are.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# # Check for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Check for null values

# %%
df.isna()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False     True         True      True
# 148651  False         False     False     True         True      True
# 148652  False         False     False     True         True      True
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %% [markdown]
# # Find the percent of missing values in each column

# %%
df.isna().sum() * (100/len(df))
# Out:
# Id                    0.000000
# EmployeeName          0.000000
# JobTitle              0.000000
# BasePay               0.409676
# OvertimePay           0.002691
# OtherPay              0.002691
# Benefits             24.326961
# TotalPay              0.000000
# TotalPayBenefits      0.000000
# Year                  0.000000
# Notes               100.000000
# Agency                0.000000
# Status              100.000000
# dtype: float64

# %% [markdown]
# # drop columns with completely missing values

# %%
df.drop(['Notes' , 'Status']  , axis = 1 , inplace = True)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # drop Agency column with zero variance

# %%
df['Agency'].unique()
df.drop(['Agency'] , axis = 1 , inplace = True)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # check data types

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# dtype: object

# %% [markdown]
# # change id and year data types from integer to string

# %%
df['Id'] = df.apply(str)
df['Year'] = df.apply(str)
df.dtypes
# Out:
# Id                   object
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                 object
# dtype: object

# %% [markdown]
# # Find summary of data statistics

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448841    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits
# count  148654.000000     148654.000000
# mean    74768.321972      93692.554811
# std     50517.005274      62793.533483
# min      -618.130000       -618.130000
# 25%     36168.995000      44065.650000
# 50%     71426.610000      92404.090000
# 75%    105839.135000     132876.450000
# max    567595.430000     567595.430000

# %% [markdown]
# # find indices of BasePay value less than 0

# %%
Negative_BP = df[df['BasePay'] < 0].index
print ("Indices of BasePay < 0 = " , Negative_BP)
# Out:
# Indices of BasePay < 0 =  Int64Index([72832, 72865, 72872, 72874, 72878, 72884, 72888, 72894, 72908,
#             72920, 72922],
#            dtype='int64')

# %% [markdown]
# # find all indices with negative values

# %%
Negative_BP = df[df['BasePay'] < 0].index
print ("Indices of BasePay < 0 = " , Negative_BP)

Negative_OTP = df[df['OvertimePay'] < 0].index
print ("Indices of OvertimePay < 0 = " , Negative_OTP)

Negative_OP = df[df['OtherPay'] < 0].index
print ("Indices of OtherPay < 0 = " , Negative_OP)

Negative_B = df[df['Benefits'] < 0].index
print ("Indices of Benefits < 0 = " , Negative_B)

Negative_TP = df[df['TotalPay'] < 0].index
print ("Indices of TotalPay < 0 = " , Negative_TP)

Negative_TPB = df[df['TotalPayBenefits'] < 0].index
print ("Indices of TotalPayBenefits < 0 = " , Negative_TPB)

Negative_Indices = Negative_BP.append(Negative_OTP)
Negative_Indices = Negative_Indices.append(Negative_OP)
Negative_Indices = Negative_Indices.append(Negative_B)
Negative_Indices = Negative_Indices.append(Negative_TP)

print ("Indices with Negative Values : " , Negative_Indices)
# Out:
# Indices of BasePay < 0 =  Int64Index([72832, 72865, 72872, 72874, 72878, 72884, 72888, 72894, 72908,
#             72920, 72922],
#            dtype='int64')
# Indices of OvertimePay < 0 =  Int64Index([90714], dtype='int64')
# Indices of OtherPay < 0 =  Int64Index([84969, 93200, 96168, 107184, 148653], dtype='int64')
# Indices of Benefits < 0 =  Int64Index([110528, 110529, 110530, 144099], dtype='int64')
# Indices of TotalPay < 0 =  Int64Index([148653], dtype='int64')
# Indices of TotalPayBenefits < 0 =  Int64Index([110528, 110529, 110530, 148653], dtype='int64')
# Indices with Negative Values :  Int64Index([ 72832,  72865,  72872,  72874,  72878,  72884,  72888,  72894,
#              72908,  72920,  72922,  90714,  84969,  93200,  96168, 107184,
#             148653, 110528, 110529, 110530, 144099, 148653],
#            dtype='int64')

# %% [markdown]
# # find length of indices with negative values

# %%
Length_Indices = len(Negative_Indices)
print ("The Length of Indices with negative values : " , Length_Indices)
# Out:
# The Length of Indices with negative values :  22

# %% [markdown]
# # find shape of dataframe before dropping negative values

# %%
df
# Out:
#          Id       EmployeeName  \
# 0       NaN     NATHANIEL FORD
# 1       NaN       GARY JIMENEZ
# 2       NaN     ALBERT PARDINI
# 3       NaN  CHRISTOPHER CHONG
# 4       NaN    PATRICK GARDNER
# ...     ...                ...
# 148649  NaN      Roy I Tillery
# 148650  NaN       Not provided
# 148651  NaN       Not provided
# 148652  NaN       Not provided
# 148653  NaN          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # drop negative values

# %%
df.drop(Negative_Indices , inplace = True)

# %% [markdown]
# # reset the indices

# %%
df.reset_index(drop = True , inplace = True )

# %% [markdown]
# # find shape of dataframe after dropping negative values

# %%
df.shape
# Out:
# (148633, 10)

# %% [markdown]
# # find indices of zero TotalPay

# %%
df[df['TotalPay'] == 0].index
# Out:
# Int64Index([ 36156,  36157,  36158,  70877,  70927,  70928,  70932,  70933,
#              70942,  70956,
#             ...
#             148623, 148624, 148625, 148626, 148627, 148628, 148629, 148630,
#             148631, 148632],
#            dtype='int64', length=365)

# %% [markdown]
# # what's your conclusion about it

# %%
print (">> Meaning that There are many employess didn't have Totalpay or there are missing values")
# Out:
# >> Meaning that There are many employess didn't have Totalpay or there are missing values

# %% [markdown]
# # find indices of zero TotalPayBenefits

# %%
Zero_TPB = df[df['TotalPayBenefits'] == 0].index
print (Zero_TPB)
# Out:
# Int64Index([ 36156,  36157,  36158, 148606, 148607, 148608, 148609, 148610,
#             148611, 148612, 148613, 148614, 148615, 148616, 148617, 148618,
#             148619, 148620, 148621, 148622, 148623, 148624, 148625, 148626,
#             148627, 148628, 148629, 148630, 148631, 148632],
#            dtype='int64')

# %% [markdown]
# # Based on ur conclusion what should you do

# %%
df.drop(Zero_TPB , inplace = True)
df.reset_index(drop = True , inplace = True )
df
# Out:
#          Id        EmployeeName  \
# 0       NaN      NATHANIEL FORD
# 1       NaN        GARY JIMENEZ
# 2       NaN      ALBERT PARDINI
# 3       NaN   CHRISTOPHER CHONG
# 4       NaN     PATRICK GARDNER
# ...     ...                 ...
# 148598  NaN      Kenneth Mackey
# 148599  NaN  Jacqueline Hubbard
# 148600  NaN     Deborah B Honig
# 148601  NaN  Lorraine Rosenthal
# 148602  NaN     Renato C Gurion
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148598                                Transit Operator       0.00
# ...

# %% [markdown]
# # Are you ready for filling missing values now?
# ## Data Analysis

# %%
#What is the average BasePay ?
df['BasePay'].mean()
# Out:
# 66343.0809077829

# %%
#What is the highest amount of OvertimePay in the dataset ?
#print (df.sort_values(by= 'OvertimePay').tail())
print (df['OvertimePay'].max())
# Out:
# 245131.88

# %%
#What is the job title of JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).
df[df['EmployeeName'] == "JOSEPH DRISCOLL"]
# Out:
#      Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  NaN  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits Year
# 24  31909.28       NaN  270324.91         270324.91  NaN

# %%
df[df['EmployeeName'] == "JOSEPH DRISCOLL"]['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
#How much does JOSEPH DRISCOLL make (including benefits)?
df[df['EmployeeName'] == "JOSEPH DRISCOLL"]['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
#What is the name of highest paid person (including benefits)?
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
#What is the name of lowest paid person (including benefits)?
df[df['TotalPayBenefits'] == df['TotalPayBenefits'].min()]['EmployeeName']
# Out:
# 36155    JOE BROWN JR
# Name: EmployeeName, dtype: object

# %%
#What was the average (mean) BasePay of all employees per year? (2011-2014) ?
# df['Year'] = pd.to_numeric(df['Year'])
# df.dtypes
df.groupby('Year').mean()['BasePay']
# Out:
# Series([], Name: BasePay, dtype: float64)

# %%
#How many unique job titles are there?
df['JobTitle'].nunique()
# Out:
# 2158

# %%
#What are the top 5 most common jobs?
# Jops = df.groupby('JobTitle').count()
# common = Jops.sort_values(by = 'EmployeeName' , ascending=False)[:5]
# common['EmployeeName']

df.JobTitle.value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4388
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2418
# Name: JobTitle, dtype: int64

# %%
#How many Job Titles were represented by only one person in 2013?
# Job_T = df[df['Year'] == 2013]
# Person = Job_T.groupby('JobTitle').count()
# M = Person[Person['EmployeeName'] == 1]
# M.count()['EmployeeName']

sum(df[df['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 0

# %%
#How many people have the word Chief in their job title?
def chief(job_title):
  num = 0
  if 'chief' in job_title.lower():
    num +=1 
  return num

sum(df['JobTitle'].apply(chief))
# Out:
# 627

# %%
#Is there a correlation between length of the Job Title string, Benefit and TotalPay?
df[['JobTitle' , 'Benefits' , 'TotalPay']]
# Out:
#                                               JobTitle  Benefits   TotalPay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY       NaN  567595.43
# 1                      CAPTAIN III (POLICE DEPARTMENT)       NaN  538909.28
# 2                      CAPTAIN III (POLICE DEPARTMENT)       NaN  335279.91
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       NaN  332343.61
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)       NaN  326373.19
# ...                                                ...       ...        ...
# 148598                                Transit Operator      0.00      15.35
# 148599                                    Senior Clerk      0.00      13.77
# 148600                       Attorney (Civil/Criminal)      0.13      13.35
# 148601                                    Senior Clerk      0.00      12.89
# 148602                                Registered Nurse      1.24       6.00
#
# [148603 rows x 3 columns]

# %%
df['Len_JT'] = df['JobTitle'].apply(len)
df[['Len_JT' , 'Benefits' , 'TotalPay']]
# Out:
#         Len_JT  Benefits   TotalPay
# 0           46       NaN  567595.43
# 1           31       NaN  538909.28
# 2           31       NaN  335279.91
# 3           36       NaN  332343.61
# 4           44       NaN  326373.19
# ...        ...       ...        ...
# 148598      16      0.00      15.35
# 148599      12      0.00      13.77
# 148600      25      0.13      13.35
# 148601      12      0.00      12.89
# 148602      16      1.24       6.00
#
# [148603 rows x 3 columns]

# %%
df[['Len_JT' , 'Benefits' , 'TotalPay']].corr()
# Out:
#             Len_JT  Benefits  TotalPay
# Len_JT    1.000000 -0.021766 -0.015589
# Benefits -0.021766  1.000000  0.884004
# TotalPay -0.015589  0.884004  1.000000
